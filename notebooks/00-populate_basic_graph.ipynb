# %% [markdown]
# # Let's get started with Method 1...
#
# If you are running this notebook on Google Colab, run the following cell:

# %%
# !pip install py2neo
# !pip install wikipedia
# !pip install spacy==3.0.3

# %%
import json
import re
import urllib
from pprint import pprint
import time
from tqdm import tqdm

from py2neo import Node, Graph, Relationship, NodeMatcher
from py2neo.bulk import merge_nodes

import numpy as np
import pandas as pd
import wikipedia
from sklearn.metrics.pairwise import cosine_similarity

import spacy
from spacy.lang.en.stop_words import STOP_WORDS
from spacy.matcher import Matcher
from spacy.tokens import Doc, Span, Token

print(spacy.__version__)
# Out:
# 3.6.1

# %% [markdown]
# # Configure spacy
#
# Prior to actually using spacy, we need to load in some models.  The basic model is their small core library, taken from the web: `en_core_web_sm`, which provides good, basic functionality with a small download size (< 20 MB).  However, one drawback of this basic model is that it doesn't have full word vectors.  Instead, it comes with context-sensitive tensors.  You can still do things like text similarity with it, but if you want to use spacy to create good word vectors, you should use a larger model such as `en_core_web_md` or`en_core_web_lg` since the small models are not known for accuracy.  You can also use a variety of third-party models, but that is beyond the scope of this workshop.  Again, choose the model that works best with your setup.
#
# In general, to load the models we use the following command:
#
# `python3 -m spacy download en_core_web_md`
#
# This has already been completed in the container, but if you want to add other models you can do this either as a cell in this notebook or via the CLI.
#
# ## API key for Google Knowledge Graph
#
# See below for instructions on how to create this key.  When you have the key, save it to a file called `.api_key` in this directory.  If you are doing this on Google Colab, mount your local Google Drive directory and store it there.

# %% [markdown]
# ## If you are running this in Google Colab, install the language model using this command:

# %%
# !python -m spacy download en_core_web_md

# %%
SUBJECTS = ["nsubj", "nsubjpass", "csubj", "csubjpass", "agent", "expl"]
VERBS = ['ROOT', 'advcl']
OBJECTS = ["dobj", "dative", "attr", "oprd", 'pobj']
ENTITY_LABELS = ['PERSON', 'NORP', 'GPE', 'ORG', 'FAC', 'LOC', 'PRODUCT', 'EVENT', 'WORK_OF_ART']

api_key = open('.api_key').read()
# AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY

non_nc = spacy.load('en_core_web_md')

nlp = spacy.load('en_core_web_md')
nlp.add_pipe('merge_noun_chunks') #  Noun chunks are phrases that include a noun and its modifiers (e.g., "the big cat").

print(non_nc.pipe_names)
print(nlp.pipe_names)
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner', 'merge_noun_chunks']

# %% [markdown]
# # Query Google Knowledge Graph
#
# To query the Google Knowledge Graph you will require an API key, which permits you to have 100,000 read calls per day per project for free.  That will be more than sufficient for this workshop.  To obtain your key, follow [these instructions](https://developers.google.com/knowledge-graph/how-tos/authorizing).

# %%
def query_google(query, api_key, limit=10, indent=True, return_lists=True):
    
    text_ls = []
    node_label_ls = []
    url_ls = []
    
    
    params = {
        'query': query,
        'limit': limit,
        'indent': indent,
        'key': api_key,
    }   
    print(f'params= {params}\n')
    service_url = 'https://kgsearch.googleapis.com/v1/entities:search'
    url = service_url + '?' + urllib.parse.urlencode(params)
    response = json.loads(urllib.request.urlopen(url).read())
    
    if return_lists:
        for element in response['itemListElement']:

            try:
                node_label_ls.append(element['result']['@type'])
            except:
                node_label_ls.append('')

            try:
                text_ls.append(element['result']['detailedDescription']['articleBody'])
            except:
                text_ls.append('')
                
            try:
                url_ls.append(element['result']['detailedDescription']['url'])
            except:
                url_ls.append('')
                
        return text_ls, node_label_ls, url_ls
    
    else:
        return response

# %%
query_google("Best Cat Ear Headphones", api_key)
# Out:
# params= {'query': 'Best Cat Ear Headphones', 'limit': 10, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
# (["Apple Inc. has produced and sold headphones since 2001, available for standalone purchase and bundled with iPhone and iPod products. Apple's current product line consists of EarPods, AirPods and AirPods Pro, and AirPods Max."],
#  [['Thing', 'ProductModel']],
#  ['https://en.wikipedia.org/wiki/Apple_headphones'])

# %% [markdown]
# # Helper functions for text cleaning
#
# As with any data science project, we have a lot of cleaning to do!  These next functions do things like removing
#
# - special characters (`remove_special_characters`)
# - stop words and punctuation (`remove_stop_words_and_punct`)
# - dates (`remove_dates`)
# - duplicates (`remove_duplicates`)
#   - Duplicates crop up many times during this process and we will be battling them a lot!
#
# Then, we can get to the heart of the matter, `create_svo_triples`.

# %%
def remove_special_characters(text):
    
    regex = re.compile(r'[\n\r\t]')
    clean_text = regex.sub(" ", text)
    
    return clean_text


def remove_stop_words_and_punct(text, print_text=False):
    
    result_ls = []
    rsw_doc = non_nc(text)
    
    for token in rsw_doc:
        if print_text:
            print(token, token.is_stop)
            print('--------------')
        if not token.is_stop and not token.is_punct:
            result_ls.append(str(token))
    
    result_str = ' '.join(result_ls)

    return result_str


def create_svo_lists(doc, print_lists):
    
    subject_ls = []
    verb_ls = []
    object_ls = []

    for token in doc:
        if token.dep_ in SUBJECTS:
            subject_ls.append((token.lower_, token.idx))
        elif token.dep_ in VERBS:
            verb_ls.append((token.lemma_, token.idx))
        elif token.dep_ in OBJECTS:
            object_ls.append((token.lower_, token.idx))

    if print_lists:
        print('SUBJECTS: ', subject_ls)
        print('VERBS: ', verb_ls)
        print('OBJECTS: ', object_ls)
    
    return subject_ls, verb_ls, object_ls


def remove_duplicates(tup, tup_posn):
    
    check_val = set()
    result = []
    
    for i in tup:
        if i[tup_posn] not in check_val:
            result.append(i)
            check_val.add(i[tup_posn])
            
    return result


def remove_dates(tup_ls):
    
    clean_tup_ls = []
    for entry in tup_ls:
        if not entry[2].isdigit():
            clean_tup_ls.append(entry)
    return clean_tup_ls


def create_svo_triples(text, print_lists=False):
    
    clean_text = remove_special_characters(text)
    doc = nlp(clean_text)
    subject_ls, verb_ls, object_ls = create_svo_lists(doc, print_lists=print_lists)
    
    graph_tup_ls = []
    dedup_tup_ls = []
    clean_tup_ls = []
    
    for subj in subject_ls: 
        for obj in object_ls:
            
            dist_ls = []
            
            for v in verb_ls:
                
                # Assemble a list of distances between each object and each verb
                dist_ls.append(abs(obj[1] - v[1]))
                
            # Get the index of the verb with the smallest distance to the object 
            # and return that verb
            index_min = min(range(len(dist_ls)), key=dist_ls.__getitem__)
            
            # Remve stop words from subjects and object.  Note that we do this a bit
            # later down in the process to allow for proper sentence recognition.

            no_sw_subj = remove_stop_words_and_punct(subj[0])
            no_sw_obj = remove_stop_words_and_punct(obj[0])
            
            # Add entries to the graph iff neither subject nor object is blank
            if no_sw_subj and no_sw_obj:
                tup = (no_sw_subj, verb_ls[index_min][0], no_sw_obj)
                graph_tup_ls.append(tup)
        
        #clean_tup_ls = remove_dates(graph_tup_ls)
    
    dedup_tup_ls = remove_duplicates(graph_tup_ls, 2)
    clean_tup_ls = remove_dates(dedup_tup_ls)
    
    return clean_tup_ls

# %% [markdown]
# # Let's get started!

# %%
text= wikipedia.summary('barack obama')
text
# Out:
# "Barack Hussein Obama II (  bə-RAHK hoo-SAYN oh-BAH-mə; born August 4, 1961) is an American politician who served as the 44th president of the United States from 2009 to 2017. A member of the Democratic Party, he was the first African-American  president. Obama previously served as a U.S. senator representing Illinois from 2005 to 2008 and as an Illinois state senator from 1997 to 2004, and worked as a civil rights lawyer and university lecturer. \nObama was born in Honolulu, Hawaii. After graduating from Columbia University in 1983, he worked as a community organizer in Chicago. In 1988, he enrolled in Harvard Law School, where he was the first black president of the Harvard Law Review. After graduating, he became a civil rights attorney and an academic, teaching constitutional law at the University of Chicago Law School from 1992 to 2004. Turning to elective politics, he represented the 13th district in the Illinois Senate from 1997 until 2004, when he successfully ran for the U.S. Senate. In 2008, after a close primary campaign against Hillary Clinton, he was nominated by the Democratic Party for president and chose Joe Biden as his running mate. Obama was elected President, defeating Republican nominee John McCain in the presidential election and was inaugurated on January 20, 2009. Nine months later, he was named the 2009 Nobel Peace Prize laureate, a decision that drew a mixture of praise and criticism.\nObama's first-term actions addressed the global financial crisis and included a major stimulus package, a partial extension of George W. Bush's tax cuts, legislation to reform health care, a major financial regulation reform bill, and the end of a major U.S. military presence in Iraq. Obama also appointed Supreme Court justices Sonia Sotomayor and Elena Kagan, the former being the first Hispanic American on the Supreme Court. He ordered the counterterrorism raid which killed Osama bin Laden and downplayed Bush's counterinsurgency model, expanding air strikes and making extensive use of special forces while encouraging greater reliance on host-government militaries. Obama also ordered military involvement in Libya in order to implement UN Security Council Resolution 1973, contributing to the overthrow of Muammar Gaddafi.\nAfter winning re-election by defeating Republican opponent Mitt Romney, Obama was sworn in for a second term on January 20, 2013. In his second term, Obama took steps to combat climate change, signing a major international climate agreement and an executive order to limit carbon emissions. Obama also presided over the implementation of the Affordable Care Act and other legislation passed in his first term, and he negotiated a nuclear agreement with Iran and normalized relations with Cuba. The number of American soldiers in Afghanistan fell dramatically during Obama's second term, though U.S. soldiers remained in the country throughout Obama's presidency. Obama promoted inclusion for LGBT Americans, culminating in the Supreme Court's decision to strike down same-sex marriage bans as unconstitutional in Obergefell v. Hodges.\nDuring Obama's terms as president, the United States' reputation abroad, as well as the American economy, significantly improved. Obama left office on January 20, 2017, and continues to reside in Washington, D.C. His presidential library in Chicago began construction in 2021. Since leaving office, Obama has remained active in Democratic politics, including campaigning for candidates in various American elections. Outside of politics, Obama has published three bestselling books: Dreams from My Father (1995), The Audacity of Hope (2006) and A Promised Land (2020). Rankings by scholars and historians, in which he has been featured since 2010, place him in the middle to upper tier of American presidents."

# %% [markdown]
# # More helper functions
#
# Now that we have our text clean, we are ready to start getting information about all of the objects in the list (`get_obj_properties`) such as:
#
# - any identified node labels
# - any descriptions
# - any URLs
#
# These will be used to create node properties for all of the objects.  We end this section with allowing the ML models build into spacy to create word vector embeddings for each node based on the node description.  (If no description is provided, this will be an array of zeros.)

# %%
def get_obj_properties(tup_ls):
    
    init_obj_tup_ls = []
    
    for tup in tup_ls:

        try:
            text, node_label_ls, url = query_google(tup[2], api_key, limit=1)
            new_tup = (tup[0], tup[1], tup[2], text[0], node_label_ls[0], url[0])
        except:
            new_tup = (tup[0], tup[1], tup[2], [], [], [])
        
        init_obj_tup_ls.append(new_tup)
        
    return init_obj_tup_ls


def add_layer(tup_ls):

    svo_tup_ls = []
    
    for tup in tup_ls:
        
        if tup[3]:
            svo_tup = create_svo_triples(tup[3])
            svo_tup_ls.extend(svo_tup)
        else:
            continue
    
    return get_obj_properties(svo_tup_ls)
        

def subj_equals_obj(tup_ls):
    
    new_tup_ls = []
    
    for tup in tup_ls:
        if tup[0] != tup[2]:
            new_tup_ls.append((tup[0], tup[1], tup[2], tup[3], tup[4], tup[5]))
            
    return new_tup_ls


def check_for_string_labels(tup_ls):
    # This is for an edge case where the object does not get fully populated
    # resulting in the node labels being assigned to string instead of list.
    # This may not be strictly necessary and the lines using it are commnted out
    # below.  Run this function if you come across this case.
    
    clean_tup_ls = []
    
    for el in tup_ls:
        if isinstance(el[2], list):
            clean_tup_ls.append(el)
            
    return clean_tup_ls


def create_word_vectors(tup_ls):
    '''creating the word vectors'''

    new_tup_ls = []
    
    for tup in tup_ls:
        if tup[3]:
            doc = nlp(tup[3])
            new_tup = (tup[0], tup[1], tup[2], tup[3], tup[4], tup[5], doc.vector)
        else:
            new_tup = (tup[0], tup[1], tup[2], tup[3], tup[4], tup[5], np.random.uniform(low=-1.0, high=1.0, size=(300,)))
        new_tup_ls.append(new_tup)
        
    return new_tup_ls

# %% [markdown]
# # Let's now run this step by step...

# %%
# %%time
initial_tup_ls = create_svo_triples(text, print_lists=False)
# Out:
# CPU times: user 30 s, sys: 817 µs, total: 30 s
# Wall time: 30 s

# %%
initial_tup_ls[0:3]
# Out:
# [('barack hussein', 'be', 'american politician'),
#  ('barack hussein', 'be', '44th president'),
#  ('barack hussein', 'member', 'united states')]

# %%
init_obj_tup_ls = get_obj_properties(initial_tup_ls)
init_obj_tup_ls
# Out:
# params= {'query': 'american politician', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': '44th president', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'united states', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'democratic party', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'african american   president', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'u.s senator', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'illinois', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'illinois state senator', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'civil rights lawyer', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'honolulu', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'columbia university', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'community organizer', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'chicago', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'harvard law school', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'black president', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'harvard law review', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'civil rights attorney', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'constitutional law', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'school', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'elective politics', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': '13th district', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'illinois senate', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'u.s senate', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'close primary campaign', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'hillary clinton', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'president', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'joe biden', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'running mate', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'republican nominee john mccain', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'presidential election', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'january', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': '2009 nobel peace prize laureate', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'mixture', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'praise', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'global financial crisis', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'major stimulus package', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'george w. bush tax cuts', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'health care', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'major u.s military presence', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'iraq', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'supreme court justices', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'hispanic american', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'supreme court', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'counterterrorism raid', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'osama bin laden', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'bush counterinsurgency model', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'air strikes', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'extensive use', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'special forces', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'greater reliance', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'host government militaries', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'military involvement', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'libya', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'order', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'un security council resolution', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'overthrow', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'muammar gaddafi', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'election', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'republican opponent mitt romney', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'second term', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'steps', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'climate change', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'major international climate agreement', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'carbon emissions', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'implementation', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'affordable care act', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'term', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'nuclear agreement', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'iran', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'cuba', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'american soldiers', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'afghanistan', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'obama second term', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'country', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'obama presidency', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'inclusion', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'lgbt americans', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'supreme court decision', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'sex marriage bans', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'obergefell', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'hodges', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'obama terms', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'office', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'washington', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'construction', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'democratic politics', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'candidates', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'american elections', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'politics', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'bestselling books', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'father', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'hope', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'scholars', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'middle', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'upper tier', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'american presidents', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
# [('barack hussein',
#   'be',
#   'american politician',
#   'Tommy Lefroy is an international indie pop musical duo currently based in London, England, consisting of Canadian singer Tessa Mouzourakis and American singer Wynter Bethel. ',
#   ['Thing', 'MusicGroup'],
#   'https://en.wikipedia.org/wiki/Tommy_Lefroy'),
#  ('barack hussein', 'be', '44th president', [], [], []),
#  ('barack hussein',
#   'member',
#   'united states',
#   'The United States of America, commonly known as the United States or America, is a country primarily located in North America and consisting of 50 states, a federal district, five major unincorporated territories, nine Minor Outlying Islands, and 326 Indian reservations. ',
#   ['Thing', 'Place', 'Country', 'AdministrativeArea'],
#   'https://en.wikipedia.org/wiki/United_States'),
#  ('barack hussein',
#   'member',
#   'democratic party',
#   '',
#   ['Organization', 'Thing'],
#   ''),
#  ('barack hussein',
#   'be',
#   'african american   president',
#   '',
#   ['Book', 'Thing'],
#   ''),
#  ('barack hussein',
#   'serve',
#   'u.s senator',
#   'John Sidney McCain III was an American politician and United States Navy officer who served as a United States senator from Arizona from 1987 until his death in 2018. ',
#   ['Person', 'Thing'],
#   'https://en.wikipedia.org/wiki/John_McCain'),
#  ('barack hussein',
#   'serve',
#   'illinois',
#   'Illinois is a state in the Midwestern United States. The Great Lakes are to its northeast and the Mississippi River to its west. Its largest metropolitan areas are Chicago and the Metro East region of Greater St. Louis. Other metropolitan areas include Peoria and Rockford, as well as Springfield, its capital. ',
#   ['Place', 'Thing', 'AdministrativeArea'],
#   'https://en.wikipedia.org/wiki/Illinois'),
#  ('barack hussein', 'serve', 'illinois state senator', [], [], []),
#  ('barack hussein',
#   'bear',
#   'civil rights lawyer',
#   "The Lawyers' Committee for Civil Rights Under Law, or simply the Lawyers' Committee, is a civil rights organization founded in 1963 at the request of President John F. Kennedy.\n",
#   ['Thing', 'Organization', 'Corporation'],
#   "https://en.wikipedia.org/wiki/Lawyers'_Committee_for_Civil_Rights_Under_Law"),
#  ('barack hussein',
#   'bear',
#   'honolulu',
#   'Honolulu is the capital and most populous city of the U.S. state of Hawaii, which is in the Pacific Ocean. It is the unincorporated county seat of the consolidated City and County of Honolulu, situated along the southeast coast of the island of Oʻahu, and is the westernmost and southernmost major U.S. city. ',
#   ['Thing', 'City', 'Place', 'AdministrativeArea'],
#   'https://en.wikipedia.org/wiki/Honolulu'),
#  ('barack hussein',
#   'work',
#   'columbia university',
#   'Columbia University, officially titled as Columbia University in the City of New York, is a private Ivy League research university in New York City. ',
#   ['Corporation',
#    'EducationalOrganization',
#    'CollegeOrUniversity',
#    'Place',
#    'MovieTheater',
#    'Thing',
#    'Organization'],
#   'https://en.wikipedia.org/wiki/Columbia_University'),
#  ('barack hussein', 'work', 'community organizer', '', ['Thing'], ''),
#  ('barack hussein',
#   'enrol',
#   'chicago',
#   "The Chicago Bulls are an American professional basketball team based in Chicago. The Bulls compete in the National Basketball Association as a member of the league's Eastern Conference Central Division. ",
#   ['Corporation', 'Thing', 'SportsTeam', 'Organization'],
#   'https://en.wikipedia.org/wiki/Chicago_Bulls'),
#  ('barack hussein',
#   'enrol',
#   'harvard law school',
#   'Harvard Law School is the law school of Harvard University, a private research university in Cambridge, Massachusetts. Founded in 1817, Harvard Law School is the oldest continuously operating law school in the United States.\n',
#   ['CollegeOrUniversity',
#    'Thing',
#    'EducationalOrganization',
#    'MovieTheater',
#    'Organization',
#    'Corporation',
#    'Place'],
#   'https://en.wikipedia.org/wiki/Harvard_Law_School'),
#  ('barack hussein',
#   'enrol',
#   'black president',
#   'Black President is a song by South African singer Brenda Fassie. It is the sixth track on her sixth studio album, Black President, It was written by Sello "Checco" Twala, Brenda Fassie, and produced by Twala and released on February 8, 1990 through CCP Records.\n',
#   ['MusicComposition', 'Thing'],
#   'https://en.wikipedia.org/wiki/Black_President_(song)'),
#  ('barack hussein',
#   'become',
#   'harvard law review',
#   'The Harvard Law &amp; Policy Review is a law journal and the official journal of the American Constitution Society, a progressive legal organization. It was established in 2007. The journal publishes two printed editions per year, as well as additional content posted exclusively online. It is edited by Harvard Law School students and typically has a staff of approximately 75 students. ',
#   ['Periodical', 'Thing', 'CreativeWork'],
#   'https://en.wikipedia.org/wiki/Harvard_Law_%26_Policy_Review'),
#  ('barack hussein', 'become', 'civil rights attorney', [], [], []),
#  ('barack hussein',
#   'teach',
#   'constitutional law',
#   'Constitutional law is a body of law which defines the role, powers, and structure of different entities within a state, namely, the executive, the parliament or legislature, and the judiciary; as well as the basic rights of citizens and, in federal countries such as the United States and Canada, the relationship between the central government and state, provincial, or territorial governments.\n',
#   ['Thing'],
#   'https://en.wikipedia.org/wiki/Constitutional_law'),
#  ('barack hussein',
#   'turn',
#   'school',
#   'A school is an educational institution designed to provide learning spaces and learning environments for the teaching of students under the direction of teachers. Most countries have systems of formal education, which is sometimes compulsory. In these systems, students progress through a series of schools. ',
#   ['Thing'],
#   'https://en.wikipedia.org/wiki/School'),
#  ('barack hussein', 'turn', 'elective politics', [], [], []),
#  ('barack hussein',
#   'represent',
#   '13th district',
#   'District 13, is a 2004 French action film directed by Pierre Morel and written and produced by Luc Besson. It depicts parkour in several stunt sequences completed without wires or computer-generated imagery. ',
#   ['CreativeWork', 'Movie', 'Thing'],
#   'https://en.wikipedia.org/wiki/District_13'),
#  ('barack hussein',
#   'represent',
#   'illinois senate',
#   'The Illinois Senate is the upper chamber of the Illinois General Assembly, the legislative branch of the government of the State of Illinois in the United States. The body was created by the first state constitution adopted in 1818. ',
#   ['Organization', 'Thing'],
#   'https://en.wikipedia.org/wiki/Illinois_Senate'),
#  ('barack hussein',
#   'nominate',
#   'u.s senate',
#   'The United States Senate is the upper chamber of the United States Congress, with the House of Representatives being the lower chamber. Together they compose the national bicameral legislature of the United States.\nThe composition and powers of the Senate are established by Article One of the United States Constitution. ',
#   ['Thing', 'Organization'],
#   'https://en.wikipedia.org/wiki/United_States_Senate'),
#  ('barack hussein', 'nominate', 'close primary campaign', [], [], []),
#  ('barack hussein',
#   'nominate',
#   'hillary clinton',
#   'Hillary Diane Rodham Clinton is an American politician and diplomat who served as the 67th United States secretary of state under president Barack Obama from 2009 to 2013, as a U.S. senator representing New York from 2001 to 2009, and as the first lady of the United States as the wife of president Bill Clinton from 1993 to 2001. ',
#   ['Person', 'Thing'],
#   'https://en.wikipedia.org/wiki/Hillary_Clinton'),
#  ('barack hussein',
#   'nominate',
#   'president',
#   'President is a common title for the head of state in most republics. The president of a nation is, generally speaking, the head of the government and the fundamental leader of the country or the ceremonial head of state.\n',
#   ['Thing'],
#   'https://en.wikipedia.org/wiki/President_(government_title)'),
#  ('barack hussein',
#   'elect',
#   'joe biden',
#   'Joseph Robinette Biden Jr. is an American politician who is the 46th and current president of the United States. A member of the Democratic Party, he previously served as the 47th vice president from 2009 to 2017 under President Barack Obama and represented Delaware in the United States Senate from 1973 to 2009.\n',
#   ['Person', 'Thing'],
#   'https://en.wikipedia.org/wiki/Joe_Biden'),
#  ('barack hussein',
#   'elect',
#   'running mate',
#   'A running mate is a person running together with another person on a joint ticket during an election. The term is most often used in reference to the person in the subordinate position but can also properly be used when referring to both candidates, such as by saying Joe Biden and Kamala Harris, and Uhuru Kenyatta and William Ruto, were running mates in relation to the presidential elections held in the United States in 2020 and Kenya in 2013 respectively.',
#   ['Thing'],
#   'https://en.wikipedia.org/wiki/Running_mate'),
#  ('barack hussein',
#   'defeat',
#   'republican nominee john mccain',
#   'John Sidney McCain III was an American politician and United States Navy officer who served as a United States senator from Arizona from 1987 until his death in 2018. ',
#   ['Thing', 'Person'],
#   'https://en.wikipedia.org/wiki/John_McCain'),
#  ('barack hussein',
#   'defeat',
#   'presidential election',
#   'Presidential elections were held in France on 10 and 24 April 2022. As no candidate won a majority in the first round, a runoff was held, in which Emmanuel Macron defeated Marine Le Pen and was re-elected as President of France. ',
#   ['Event', 'Thing'],
#   'https://en.wikipedia.org/wiki/2022_French_presidential_election'),
#  ('barack hussein',
#   'name',
#   'january',
#   "January is the first month of the year in the Julian and Gregorian calendars and is also the first of seven months to have a length of 31 days. The first day of the month is known as New Year's Day. ",
#   ['Thing'],
#   'https://en.wikipedia.org/wiki/January'),
#  ('barack hussein',
#   'name',
#   '2009 nobel peace prize laureate',
#   'The 2010 Nobel Peace Prize was awarded to imprisoned Chinese human rights activist Liu Xiaobo "for his long and non-violent struggle for fundamental human rights in China". ',
#   ['Event', 'Thing'],
#   'https://en.wikipedia.org/wiki/2010_Nobel_Peace_Prize'),
#  ('barack hussein',
#   'address',
#   'mixture',
#   'In chemistry, a mixture is a material made up of two or more different chemical substances which are not chemically bonded. A mixture is the physical combination of two or more substances in which the identities are retained and are mixed in the form of solutions, suspensions and colloids.\n',
#   ['Thing'],
#   'https://en.wikipedia.org/wiki/Mixture'),
#  ('barack hussein',
#   'address',
#   'praise',
#   'Praise as a form of social interaction expresses recognition, reassurance or admiration.\nPraise is expressed verbally as well as by body language.\n',
#   ['Thing'],
#   'https://en.wikipedia.org/wiki/Praise'),
#  ('barack hussein',
#   'address',
#   'global financial crisis',
#   '',
#   ['MusicRecording', 'Thing', 'CreativeWork'],
#   ''),
#  ('barack hussein', 'address', 'major stimulus package', [], [], []),
#  ('barack hussein',
#   'address',
#   'george w. bush tax cuts',
#   'The phrase Bush tax cuts refers to changes to the United States tax code passed originally during the presidency of George W. Bush and extended during the presidency of Barack Obama, through:\nEconomic Growth and Tax Relief Reconciliation Act of 2001\nJobs and Growth Tax Relief Reconciliation Act of 2003\n',
#   ['Thing'],
#   'https://en.wikipedia.org/wiki/Bush_tax_cuts'),
#  ('barack hussein',
#   'appoint',
#   'health care',
#   'Health care, or healthcare, is the improvement of health via the prevention, diagnosis, treatment, amelioration or cure of disease, illness, injury, and other physical and mental impairments in people. ',
#   ['Thing'],
#   'https://en.wikipedia.org/wiki/Health_care'),
#  ('barack hussein', 'appoint', 'major u.s military presence', [], [], []),
#  ('barack hussein',
#   'appoint',
#   'iraq',
#   '',
#   ['DefenceEstablishment', 'Place', 'AdministrativeArea', 'Country', 'Thing'],
#   ''),
#  ('barack hussein', 'appoint', 'supreme court justices', '', ['Thing'], ''),
#  ('barack hussein',
#   'order',
#   'hispanic american',
#   'Hispanic and Latino Americans are Americans of Spaniard and/or Latin American ancestry. These demographics include all Americans who identify as Hispanic or Latino regardless of ancestry. ',
#   ['Thing'],
#   'https://en.wikipedia.org/wiki/Hispanic_and_Latino_Americans'),
#  ('barack hussein',
#   'order',
#   'supreme court',
#   'The Supreme Court of the United States is the highest court in the federal judiciary of the United States. It has ultimate appellate jurisdiction over all federal court cases, and over state court cases that involve a point of U.S. ',
#   ['Place',
#    'TouristAttraction',
#    'GovernmentOrganization',
#    'Organization',
#    'Thing',
#    'Corporation'],
#   'https://en.wikipedia.org/wiki/Supreme_Court_of_the_United_States'),
#  ('barack hussein',
#   'order',
#   'counterterrorism raid',
#   '',
#   ['Book', 'Thing'],
#   ''),
#  ('barack hussein',
#   'order',
#   'osama bin laden',
#   'Zero Dark Thirty is a 2012 American action thriller film directed by Kathryn Bigelow and written by Mark Boal. The film dramatizes the nearly decade-long international manhunt for Osama bin Laden, leader of the terrorist network Al-Qaeda, after the September 11 attacks. ',
#   ['Thing', 'CreativeWork', 'Movie'],
#   'https://en.wikipedia.org/wiki/Zero_Dark_Thirty'),
#  ('barack hussein', 'expand', 'bush counterinsurgency model', [], [], []),
#  ('barack hussein', 'expand', 'air strikes', [], [], []),
#  ('barack hussein', 'expand', 'extensive use', '', ['Book', 'Thing'], ''),
#  ('barack hussein',
#   'encourage',
#   'special forces',
#   'Forces spéciales is a 2011 French war adventure film directed by Stéphane Rybojad and starring Diane Kruger, Djimon Hounsou, Denis Ménochet, Benoît Magimel, Mehdi Nebbou, and Tchéky Karyo. ',
#   ['Movie', 'Thing', 'CreativeWork'],
#   'https://en.wikipedia.org/wiki/Forces_sp%C3%A9ciales'),
#  ('barack hussein',
#   'encourage',
#   'greater reliance',
#   'Frozen in Time: The Fate of the Franklin Expedition is a book by Owen Beattie and John Geiger, first published in 1987 by Bloomsbury Publishing. ',
#   ['Thing', 'Book'],
#   'https://en.wikipedia.org/wiki/Frozen_in_Time:_The_Fate_of_the_Franklin_Expedition'),
#  ('barack hussein', 'encourage', 'host government militaries', [], [], []),
#  ('barack hussein', 'order', 'military involvement', [], [], []),
#  ('barack hussein',
#   'order',
#   'libya',
#   'Libya, officially the State of Libya, is a country in the Maghreb region in North Africa. It is bordered by the Mediterranean Sea to the north, Egypt to the east, Sudan to the southeast, Chad to the south, Niger to the southwest, Algeria to the west, and Tunisia to the northwest. ',
#   ['Place', 'AdministrativeArea', 'Country', 'Thing'],
#   'https://en.wikipedia.org/wiki/Libya'),
#  ('barack hussein',
#   'order',
#   'order',
#   'Order is one of the eight major hierarchical taxonomic ranks in Linnaean taxonomy. It is classified between family and class. In biological classification, the order is a taxonomic rank used in the classification of organisms and recognized by the nomenclature codes. ',
#   ['Thing'],
#   'https://en.wikipedia.org/wiki/Order_(biology)'),
#  ('barack hussein',
#   'order',
#   'un security council resolution',
#   'A United Nations Security Council resolution is a United Nations resolution adopted by the fifteen members of the Security Council; the United Nations body charged with "primary responsibility for the maintenance of international peace and security".\n',
#   ['Thing'],
#   'https://en.wikipedia.org/wiki/United_Nations_Security_Council_resolution'),
#  ('barack hussein',
#   'order',
#   'overthrow',
#   'In cricket, an overthrow is an additional run scored by a batter as a result of the ball not being collected by a fielder in the centre, having been thrown in from the outfield. ',
#   ['Thing'],
#   'https://en.wikipedia.org/wiki/Overthrow_(cricket)'),
#  ('barack hussein',
#   'swear',
#   'muammar gaddafi',
#   'Muammar Muhammad Abu Minyar al-Gaddafi, was a Libyan revolutionary, politician and political theorist who ruled Libya from 1969 until his assassination in 2011 by rebel forces. ',
#   ['Thing', 'Person'],
#   'https://en.wikipedia.org/wiki/Muammar_Gaddafi'),
#  ('barack hussein',
#   'swear',
#   'election',
#   'The 2021 Virginia gubernatorial election was held on November 2, 2021, to elect the next governor of Virginia. The election was concurrent with other elections for Virginia state offices. ',
#   ['Event', 'Thing'],
#   'https://en.wikipedia.org/wiki/2021_Virginia_gubernatorial_election'),
#  ('barack hussein', 'swear', 'republican opponent mitt romney', [], [], []),
#  ('barack hussein', 'swear', 'second term', [], [], []),
#  ('barack hussein',
#   'take',
#   'steps',
#   'Think and Grow Rich is a book written by Napoleon Hill and Rosa Lee Beeland released in 1937 and promoted as a personal development and self-improvement book. ',
#   ['Book', 'Thing'],
#   'https://en.wikipedia.org/wiki/Think_and_Grow_Rich'),
#  ('barack hussein',
#   'sign',
#   'climate change',
#   "In common usage, climate change describes global warming—the ongoing increase in global average temperature—and its effects on Earth's climate system. Climate change in a broader sense also includes previous long-term changes to Earth's climate. ",
#   ['Thing'],
#   'https://en.wikipedia.org/wiki/Climate_change'),
#  ('barack hussein',
#   'sign',
#   'major international climate agreement',
#   'The Paris Agreement, often referred to as the Paris Accords or the Paris Climate Accords, is an international treaty on climate change. Adopted in 2015, the agreement covers climate change mitigation, adaptation, and finance. ',
#   ['Thing'],
#   'https://en.wikipedia.org/wiki/Paris_Agreement'),
#  ('barack hussein', 'preside', 'carbon emissions', [], [], []),
#  ('barack hussein',
#   'preside',
#   'implementation',
#   'Implementation is the realization of an application, execution of a plan, idea, model, design, specification, standard, algorithm, policy, or the administration or management of a process or objective.',
#   ['Thing'],
#   'https://en.wikipedia.org/wiki/Implementation'),
#  ('barack hussein',
#   'preside',
#   'affordable care act',
#   'The Affordable Care Act, formally known as the Patient Protection and Affordable Care Act and colloquially known as Obamacare, is a landmark U.S. federal statute enacted by the 111th United States Congress and signed into law by President Barack Obama on March 23, 2010. ',
#   ['Thing'],
#   'https://en.wikipedia.org/wiki/Affordable_Care_Act'),
#  ('barack hussein',
#   'preside',
#   'term',
#   'Termites are a group of detritophagous eusocial insects which consume a wide variety of decaying plant material, generally in the form of wood, leaf litter, and soil humus. ',
#   ['Thing'],
#   'https://en.wikipedia.org/wiki/Termite'),
#  ('barack hussein',
#   'fall',
#   'nuclear agreement',
#   'The Joint Comprehensive Plan of Action, commonly known as the Iran nuclear deal or Iran deal, is an agreement on the Iranian nuclear program reached in Vienna on 14 July 2015, between Iran and the P5+1 together with the European Union.\n',
#   ['Thing'],
#   'https://en.wikipedia.org/wiki/Joint_Comprehensive_Plan_of_Action'),
#  ('barack hussein',
#   'fall',
#   'iran',
#   'Iran, also known as Persia and officially as the Islamic Republic of Iran, is a country in West Asia. It is bordered by Iraq and Turkey to the west, Azerbaijan and Armenia to the northwest, the Caspian Sea and Turkmenistan to the north, Afghanistan and Pakistan to the east, and the Gulf of Oman and the Persian Gulf to the south. ',
#   ['Place', 'Country', 'AdministrativeArea', 'Thing'],
#   'https://en.wikipedia.org/wiki/Iran'),
#  ('barack hussein',
#   'fall',
#   'cuba',
#   'Cuba, officially the Republic of Cuba, is an island country comprising the island of Cuba, as well as Isla de la Juventud and several minor archipelagos. Cuba is located where the northern Caribbean Sea, Gulf of Mexico, and Atlantic Ocean meet. ',
#   ['Place', 'Country', 'AdministrativeArea', 'Thing'],
#   'https://en.wikipedia.org/wiki/Cuba'),
#  ('barack hussein',
#   'fall',
#   'american soldiers',
#   'American Soldiers is a 2005 war film directed by Sidney J. Furie.',
#   ['CreativeWork', 'Thing', 'Movie'],
#   'https://en.wikipedia.org/wiki/American_Soldiers'),
#  ('barack hussein',
#   'fall',
#   'afghanistan',
#   '',
#   ['Place', 'Country', 'DefenceEstablishment', 'Thing', 'AdministrativeArea'],
#   ''),
#  ('barack hussein', 'fall', 'obama second term', [], [], []),
#  ('barack hussein',
#   'remain',
#   'country',
#   'A country is a distinct part of the world, such as a state, nation, or other political entity. It may be a sovereign state or make up one part of a larger state. ',
#   ['Thing'],
#   'https://en.wikipedia.org/wiki/Country'),
#  ('barack hussein', 'promote', 'obama presidency', [], [], []),
#  ('barack hussein',
#   'promote',
#   'inclusion',
#   'Inclusion in education refers to all students being able to access and gain equal opportunities to education and learning. It arose in the context of special education with an individualized education program or 504 plan, and is built on the notion that it is more effective for students with special needs to have the said mixed experience for them to be more successful in social interactions leading to further success in life. ',
#   ['Thing'],
#   'https://en.wikipedia.org/wiki/Inclusion_(education)'),
#  ('barack hussein', 'culminate', 'lgbt americans', [], [], []),
#  ('barack hussein', 'culminate', 'supreme court decision', [], [], []),
#  ('barack hussein', 'culminate', 'sex marriage bans', [], [], []),
#  ('barack hussein', 'culminate', 'obergefell', [], [], []),
#  ('barack hussein',
#   'culminate',
#   'hodges',
#   'Sunny Lane is an American pornographic actress and nude model. She is a member of the NightMoves, AVN, and XRCO Halls of Fame.',
#   ['Person', 'Thing'],
#   'https://en.wikipedia.org/wiki/Sunny_Lane'),
#  ('barack hussein', 'improve', 'obama terms', [], [], []),
#  ('barack hussein',
#   'leave',
#   'office',
#   'Microsoft Office, or simply Office, is a discontinued family of client software, server software, and services developed by Microsoft. It was first announced by Bill Gates on August 1, 1988, at COMDEX in Las Vegas. ',
#   ['Thing', 'ProductModel', 'SoftwareApplication'],
#   'https://en.wikipedia.org/wiki/Microsoft_Office'),
#  ('barack hussein',
#   'begin',
#   'washington',
#   'The Washington Commanders are a professional American football team based in the Washington metropolitan area. The Commanders compete in the National Football League as a member of the National Football Conference East division. ',
#   ['Thing', 'SportsTeam', 'Organization', 'Corporation'],
#   'https://en.wikipedia.org/wiki/Washington_Commanders'),
#  ('barack hussein',
#   'begin',
#   'construction',
#   'Construction is a general term meaning the art and science to form objects, systems, or organizations, and comes from Latin constructio and Old French construction. ',
#   ['Thing'],
#   'https://en.wikipedia.org/wiki/Construction'),
#  ('barack hussein',
#   'remain',
#   'democratic politics',
#   '',
#   ['Book', 'Thing'],
#   ''),
#  ('barack hussein', 'remain', 'candidates', '', ['Thing', 'Organization'], ''),
#  ('barack hussein',
#   'publish',
#   'american elections',
#   'The Purge: Election Year is a 2016 American dystopian political action horror film written and directed by James DeMonaco and starring Frank Grillo, Elizabeth Mitchell, and Mykelti Williamson. ',
#   ['Thing', 'Movie', 'CreativeWork'],
#   'https://en.wikipedia.org/wiki/The_Purge:_Election_Year'),
#  ('barack hussein',
#   'publish',
#   'politics',
#   'Politics is the set of activities that are associated with making decisions in groups, or other forms of power relations among individuals, such as the distribution of resources or status. ',
#   ['Thing'],
#   'https://en.wikipedia.org/wiki/Politics'),
#  ('barack hussein', 'publish', 'bestselling books', [], [], []),
#  ('barack hussein',
#   'publish',
#   'father',
#   'A father is the male parent of a child. Besides the paternal bonds of a father to his children, the father may have a parental, legal, and social relationship with the child that carries with it certain rights and obligations. ',
#   ['Thing'],
#   'https://en.wikipedia.org/wiki/Father'),
#  ('barack hussein',
#   'publish',
#   'hope',
#   "Hope is an optimistic state of mind that is based on an expectation of positive outcomes with respect to events and circumstances in one's life or the world at large.\n",
#   ['Thing'],
#   'https://en.wikipedia.org/wiki/Hope'),
#  ('barack hussein',
#   'place',
#   'scholars',
#   'A scholarship is a form of financial aid awarded to students for further education. Generally, scholarships are awarded based on a set of criteria such as academic merit, diversity and inclusion, athletic skill, and financial need.\n',
#   ['Thing'],
#   'https://en.wikipedia.org/wiki/Scholarship'),
#  ('barack hussein',
#   'place',
#   'middle',
#   'The Middle is an American television sitcom that aired on ABC from September 30, 2009, to May 22, 2018. The series, set in Indiana, follows a lower middle class family living and facing the day-to-day struggles of home life, work, and raising children. ',
#   ['TVSeries', 'CreativeWork', 'Thing'],
#   'https://en.wikipedia.org/wiki/The_Middle_(TV_series)'),
#  ('barack hussein', 'place', 'upper tier', [], [], []),
#  ('barack hussein', 'place', 'american presidents', [], [], [])]

# %%
# %%time
init_obj_tup_ls = get_obj_properties(initial_tup_ls)
new_layer_ls = add_layer(init_obj_tup_ls)
starter_edge_ls = init_obj_tup_ls + new_layer_ls
edge_ls = subj_equals_obj(starter_edge_ls)
#clean_edge_ls = check_for_string_labels(edge_ls)
#clean_edge_ls[0:3]
clean_edge_ls = edge_ls
# Out:
# params= {'query': 'american politician', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': '44th president', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'united states', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'democratic party', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
# params= {'query': 'african american   president', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'u.s senator', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'illinois', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'illinois state senator', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'civil rights lawyer', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'honolulu', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'columbia university', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'community organizer', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'chicago', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'harvard law school', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'black president', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'harvard law review', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'civil rights attorney', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'constitutional law', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'school', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'elective politics', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': '13th district', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'illinois senate', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'u.s senate', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'close primary campaign', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'hillary clinton', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'president', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'joe biden', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'running mate', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'republican nominee john mccain', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'presidential election', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'january', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': '2009 nobel peace prize laureate', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'mixture', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'praise', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'global financial crisis', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'major stimulus package', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'george w. bush tax cuts', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'health care', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'major u.s military presence', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'iraq', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'supreme court justices', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'hispanic american', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'supreme court', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'counterterrorism raid', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'osama bin laden', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'bush counterinsurgency model', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'air strikes', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'extensive use', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'special forces', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'greater reliance', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'host government militaries', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'military involvement', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'libya', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'order', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'un security council resolution', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'overthrow', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'muammar gaddafi', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'election', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'republican opponent mitt romney', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'second term', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'steps', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'climate change', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'major international climate agreement', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'carbon emissions', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'implementation', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'affordable care act', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'term', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'nuclear agreement', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'iran', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'cuba', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'american soldiers', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'afghanistan', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'obama second term', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'country', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'obama presidency', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'inclusion', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'lgbt americans', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'supreme court decision', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'sex marriage bans', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'obergefell', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'hodges', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'obama terms', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'office', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'washington', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'construction', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'democratic politics', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'candidates', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'american elections', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'politics', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'bestselling books', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'father', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'hope', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'scholars', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'middle', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'upper tier', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'american presidents', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'american politician', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': '38th mayor', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'los angeles', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'black mayor', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'office', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'longest tenure', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'mayor', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'city history', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'america', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'united states', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'country', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'north america', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': '50 states', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'american politician', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'united states senator', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'arizona', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'death', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'state', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'midwestern united states', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'northeast', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'west', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'chicago', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'greater st louis', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'peoria', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'civil rights', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'law', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'civil rights organization', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'request', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'president john f. kennedy', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'capital', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'u.s state', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'hawaii', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'pacific ocean', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'unincorporated county seat', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'consolidated city', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'honolulu', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'southeast coast', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'island', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'oʻahu', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'westernmost southernmost major u.s city', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'columbia university', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'city', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'new york', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'private ivy league research university', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'new york city', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'american professional basketball team', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'chicago', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'national basketball association', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'member', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'league eastern conference central division', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'law school', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'harvard university', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'cambridge', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'oldest continuously operating law school', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'united states', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'law journal', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'american constitution society', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'printed editions', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'year', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'harvard law school students', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'staff', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'approximately 75 students', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'body', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'law', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'role', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'different entities', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'state', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'citizens', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'federal countries', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'united states', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'central government', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'educational institution', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'learning spaces', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'environments', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'teaching', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'students', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'direction', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'teachers', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'systems', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'formal education', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'series', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'schools', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': '2004 french action film', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'pierre morel', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'luc besson', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'parkour', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'stunt sequences', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'wires', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'upper chamber', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'illinois general assembly', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'government', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'state', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'illinois', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'united states', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'state constitution', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'upper chamber', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'united states congress', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'representatives', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'lower chamber', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'national bicameral legislature', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'united states', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'senate', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'article', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'united states constitution', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'american politician', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': '67th united states secretary', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'state', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'president barack obama', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'u.s senator', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'new york', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'lady', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'united states', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'wife', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'president bill clinton', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'common title', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'head', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'state', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'republics', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'nation', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'government', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'country', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'american politician', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': '46th current president', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'united states', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'democratic party', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': '47th vice president', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'president barack obama', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'delaware', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'united states senate', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'person', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'joint ticket', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'election', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'reference', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'subordinate position', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'candidates', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'joe biden', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'mates', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'relation', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'presidential elections', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'united states', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'american politician', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'united states senator', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'arizona', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'death', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'france', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': '10 24 april', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'majority', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'round', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'marine le pen', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'president', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'month', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'year', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'julian gregorian calendars', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'seven months', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'length', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': '31 days', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'new year day', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'imprisoned chinese human rights activist liu xiaobo', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'long non violent struggle', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'fundamental human rights', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'china', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'chemistry', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'material', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'different chemical substances', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'physical combination', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'substances', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'form', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'solutions', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'form', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'social interaction', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'recognition', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'body language', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'changes', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'united states tax code', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'presidency', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'george w. bush', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'barack obama', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': '2001 jobs growth tax relief reconciliation act', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'improvement', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'health', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'prevention', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'disease', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'people', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'americans', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'spaniard and/or latin american ancestry', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'ancestry', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'united states', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'highest court', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'federal judiciary', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'ultimate appellate jurisdiction', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'federal court cases', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'state court cases', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'point', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'u.s', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': '2012 american action thriller film', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'kathryn bigelow', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'mark boal', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'nearly decade long international manhunt', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'osama bin laden', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'terrorist network', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'september 11 attacks', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'green berets', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'distinctive service headgear', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'special operations force', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'united states army', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'time', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'franklin expedition', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'book', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'owen beattie', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'bloomsbury publishing', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'libya', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'country', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'maghreb region', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'north africa', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'mediterranean sea', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'north', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'east', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'southeast', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'south', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'southwest', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'west', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'northwest', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'major hierarchical taxonomic ranks', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'linnaean taxonomy', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'family', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'biological classification', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'taxonomic rank', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'classification', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'organisms', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'nomenclature codes', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'united nations resolution', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'members', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'security council', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'primary responsibility', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'maintenance', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'international peace', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'cricket', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'additional run', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'batter', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'result', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'fielder', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'centre', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'outfield', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'libyan revolutionary politician political theorist', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'libya', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'assassination', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'rebel forces', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'november', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'governor', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'virginia', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'elections', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'virginia state offices', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'book', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'napoleon hill', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'personal development', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'common usage', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'global warming', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'ongoing increase', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'global average temperature', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'earth climate system', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'broader sense', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'previous long term changes', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'earth climate', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'paris accords', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'international treaty', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'climate change', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'climate change mitigation', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'realization', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'application', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'plan', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'process', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'patient protection affordable care act', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'obamacare', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'landmark u.s federal statute', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': '111th united states congress', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'law', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'president barack obama', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'march', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'group', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'detritophagous eusocial insects', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'wide variety', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'plant material', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'form', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'wood', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'action', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'iran nuclear deal', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'agreement', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'iranian nuclear program', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'vienna', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': '14 july', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'iran', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': '+', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'european union', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'persia', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'islamic republic', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'iran', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'country', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'west asia', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'iraq', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'west', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'northwest', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'north', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'east', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'oman', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'south', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'cuba', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'island country', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'island', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'mexico', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': '2005 war film', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'sidney j. furie', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'distinct', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'world', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'state', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'sovereign state', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'larger state', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'education', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'equal opportunities', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'context', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'special education', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'individualized education program', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'notion', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'special needs', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'said mixed experience', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'social interactions', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'success', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'life', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'american pornographic actress', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'member', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'nightmoves', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'fame', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'discontinued family', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'client software', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'microsoft', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'bill gates', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'august', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'comdex', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'las vegas', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'professional american football team', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'washington metropolitan area', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'national football league', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'member', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'national football conference east division', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'general term', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'objects', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'latin constructio', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': '2016 american dystopian political action horror film', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'james demonaco', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'frank grillo', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'set', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'activities', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'decisions', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'groups', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'power relations', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'individuals', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'distribution', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'resources', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': '2023 novel', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'emily henry', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'male parent', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'child', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'paternal bonds', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'father', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'children', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'parental legal social relationship', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'certain rights', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'optimistic state', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'mind', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'expectation', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'positive outcomes', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'respect', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'events', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'life', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'form', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'financial aid', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'students', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'education', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'set', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'criteria', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'academic merit', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'american television sitcom', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'abc', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'september', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'indiana', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'lower middle class family', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'day', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'struggles', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'home life', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# params= {'query': 'children', 'limit': 1, 'indent': True, 'key': 'AIzaSyBa5JhkkHOFF5zhEGR-zSsNnr14NImygcY'}
#
# CPU times: user 10.7 s, sys: 181 ms, total: 10.9 s
# Wall time: 1min 30s

# %%
edge_ls[0:3]
# Out:
# [('barack hussein',
#   'be',
#   'american politician',
#   "Thomas Bradley was an American politician and police officer who served as the 38th Mayor of Los Angeles from 1973 to 1993. He was the first Black mayor of Los Angeles, and his 20 years in office mark the longest tenure by any mayor in the city's history. ",
#   ['Thing', 'Person'],
#   'https://en.wikipedia.org/wiki/Tom_Bradley_(American_politician)'),
#  ('barack hussein', 'be', '44th president', [], [], []),
#  ('barack hussein',
#   'member',
#   'united states',
#   'The United States of America, commonly known as the United States or America, is a country primarily located in North America and consisting of 50 states, a federal district, five major unincorporated territories, nine Minor Outlying Islands, and 326 Indian reservations. ',
#   ['Thing', 'AdministrativeArea', 'Country', 'Place'],
#   'https://en.wikipedia.org/wiki/United_States')]

# %%
# %%time
edges_word_vec_ls = create_word_vectors(edge_ls)
# Out:
# CPU times: user 3.14 s, sys: 3 µs, total: 3.14 s
# Wall time: 3.14 s

# %% [markdown]
# # Create the node and edge lists to populate the graph with the below helper functions
#
# These functions achieve the following:
#
# 1. Deduping of the node list (`dedup`)
# 2. Under the idea that we might want to use word embeddings, we are pulling them in as a node property.  However, Neo4j doesn't work well with numpy arrays, so we convert that array to a list of floats (`convert_vec_to_ls`).
# 3. Add nodes to the graph with the `py2neo` bulk importer (`add_nodes`)
# 4. Add edges (relationships) to the graph (`add_edges`)

# %%
def dedup(tup_ls):
    
    visited = set()
    output_ls = []
    
    for tup in tup_ls:
        if not tup[0] in visited:
            visited.add(tup[0])
            output_ls.append((tup[0], tup[1], tup[2], tup[3], tup[4]))
            
    return output_ls


def convert_vec_to_ls(tup_ls):
    
    vec_to_ls_tup = []
    
    for el in tup_ls:
        vec_ls = [float(v) for v in el[4]]
        tup = (el[0], el[1], el[2], el[3], vec_ls)
        vec_to_ls_tup.append(tup)
        
    return vec_to_ls_tup


def add_nodes(tup_ls):   

    keys = ['name', 'description', 'node_labels', 'url', 'word_vec']
    merge_nodes(graph.auto(), tup_ls, ('Node', 'name'), keys=keys)
    print('Number of nodes in graph: ', graph.nodes.match('Node').count())
    
    return

# %%
def add_edges(edge_ls):
    
    edge_dc = {} 
    
    # Group tuple by verb
    # Result: {verb1: [(sub1, v1, obj1), (sub2, v2, obj2), ...],
    #          verb2: [(sub3, v3, obj3), (sub4, v4, obj4), ...]}
    
    for tup in edge_ls: 
        if tup[1] in edge_dc: 
            edge_dc[tup[1]].append((tup[0], tup[1], tup[2])) 
        else: 
            edge_dc[tup[1]] = [(tup[0], tup[1], tup[2])] 
    
    for edge_labels, tup_ls in tqdm(edge_dc.items()):   # k=edge labels, v = list of tuples
        
        tx = graph.begin()
        
        for el in tup_ls:
            source_node = nodes_matcher.match(name=el[0]).first()
            target_node = nodes_matcher.match(name=el[2]).first()
            if not source_node:
                source_node = Node('Node', name=el[0])
                tx.create(source_node)
            if not target_node:
                try:
                    target_node = Node('Node', name=el[2], node_labels=el[4], url=el[5], word_vec=el[6])
                    tx.create(target_node)
                except:
                    continue
            try:
                rel = Relationship(source_node, edge_labels, target_node)
            except:
                continue
            tx.create(rel)
        tx.commit()
    
    return

# %% [markdown]
# # Creating some lists of tuples representing the node and edge lists
#
# For our node list, we begin with the query subject (Barack Obama), which is in `edge_ls[0][0]` and put this in the variable `orig_node_tup_ls`.  We assume a node label of `Subject` and no description or word vector.  We then add all of the objects associated with the `edges_word_vec_ls` (`obj_node_tup_ls`) and combine that with the previous variable to create `full_node_tup_ls`, which we then dedupe into `dedup_node_tup_ls`.

# %%
orig_node_tup_ls = [(edge_ls[0][0], '', ['Subject'], '', np.random.uniform(low=-1.0, high=1.0, size=(300,)))]
obj_node_tup_ls = [(tup[2], tup[3], tup[4], tup[5], tup[6]) for tup in edges_word_vec_ls]
full_node_tup_ls = orig_node_tup_ls + obj_node_tup_ls
dedup_node_tup_ls = dedup(full_node_tup_ls)

# %%
len(full_node_tup_ls), len(dedup_node_tup_ls)
# Out:
# (479, 413)

# %% [markdown]
# # Create the node list that will be used to populate the graph...

# %%
node_tup_ls = convert_vec_to_ls(dedup_node_tup_ls)

# %% [markdown]
# # Populate the graph
#
# Here we establish a connection to the database, which is running on the internal Docker network called `neo4j`.  We provide it the user name and password and also create a class for matching nodes (used when we establish the edges in the graph).  Finally, we add the nodes and edges to populate the database.

# %%
# If you are using a Sandbox instance, you will want to use the following (commented) line.  
# If you are using a Docker container for your DB, use the uncommented line.
graph = Graph("bolt://34.238.38.220:7687", name="neo4j", password="attackers-resident-folders")

# graph = Graph("bolt://neo4j:7687", name="neo4j", password="kgDemo")
nodes_matcher = NodeMatcher(graph)

# %%
add_nodes(node_tup_ls)
# Out:
# Number of nodes in graph:  1071

# %%
add_edges(edges_word_vec_ls)
# Out:
# 100%|██████████| 64/64 [01:03<00:00,  1.01it/s]

# %% [markdown]
# # Entity disambiguation
#
# In this notebook we will calculate the cosine similarity of the word vectors of target nodes to try and determine the likelihood of two nodes being the same entity.  Note that you could do this directly with spacy (which defaults to cosine similarity) prior to anything above through something like:
#
# ```
# doc1 = nlp(text1)
# doc2 = nlp(text2)
# doc1.similarity(doc2)
# ```
#
# However, since we have already calculated the word vectors for each node description above, we will just use the cosine similarity built into `scikit-learn`.
#
# Note that we are creating now a complete node list since the nodes we are comparing might be either in the Barack or the Michelle Obama node lists...

# %%
def get_word_vec_similarity(node1, node2, node_ls):
    
    node1_vec = [tup[4] for tup in node_ls if tup[0] == node1]
    node2_vec = [tup[4] for tup in node_ls if tup[0] == node2]
    
    return cosine_similarity(node1_vec, node2_vec)

# %%
cs = get_word_vec_similarity('barack obama', 'president barack obama', dedup_node_tup_ls)
print(cs)
# Out:
# [[1.]]

# %% [markdown]
# ## ...OK, that one was cheating...
#
# ...because the Google Knowledge Graph knew that these were the same thing.  The NER returned these as being different nodes, but Google knew better and gave the exact description for each.  This will not necessarily be the case in more complicated knowledge graphs.

# %%
cs = get_word_vec_similarity('barack obama', 'mitch mcconnell', dedup_node_tup_ls)
print(cs)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/ubuntu/KnowledgeGraphs/notebooks/00-populate_basic_graph.ipynb Cell 40 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22456d62656464696e6773227d/home/ubuntu/KnowledgeGraphs/notebooks/00-populate_basic_graph.ipynb#X53sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> cs = get_word_vec_similarity('barack obama', 'mitch mcconnell', dedup_node_tup_ls)
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22456d62656464696e6773227d/home/ubuntu/KnowledgeGraphs/notebooks/00-populate_basic_graph.ipynb#X53sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> print(cs)
#
# /home/ubuntu/KnowledgeGraphs/notebooks/00-populate_basic_graph.ipynb Cell 40 in get_word_vec_similarity(node1, node2, node_ls)
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22456d62656464696e6773227d/home/ubuntu/KnowledgeGraphs/notebooks/00-populate_basic_graph.ipynb#X53sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> node1_vec = [tup[4] for tup in node_ls if tup[0] == node1]
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22456d62656464696e6773227d/home/ubuntu/KnowledgeGraphs/notebooks/00-populate_basic_graph.ipynb#X53sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> node2_vec = [tup[4] for tup in node_ls if tup[0] == node2]
# ----> <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22456d62656464696e6773227d/home/ubuntu/KnowledgeGraphs/notebooks/00-populate_basic_graph.ipynb#X53sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> return cosine_similarity(node1_vec, node2_vec)
#
# File ~/KnowledgeGraphs/venv/lib/python3.10/site-packages/sklearn/utils/_param_validation.py:211, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     205 try:
#     206     with config_context(
#     207         skip_parameter_validation=(
#     208             prefer_skip_nested_validation or global_skip_validation
#     209         )
#     210     ):
# --> 211         return func(*args, **kwargs)
#     212 except InvalidParameterError as e:
#     213     # When the function is just a wrapper around an estimator, we allow
#     214     # the function to delegate validation to the estimator, but we replace
#     215     # the name of the estimator by the name of the function in the error
#     216     # message to avoid confusion.
#     217     msg = re.sub(
#     218         r"parameter of \w+ must be",
#     219         f"parameter of {func.__qualname__} must be",
#     220         str(e),
#     221     )
#
# File ~/KnowledgeGraphs/venv/lib/python3.10/site-packages/sklearn/metrics/pairwise.py:1577, in cosine_similarity(X, Y, dense_output)
#    1542 """Compute cosine similarity between samples in X and Y.
#    1543
#    1544 Cosine similarity, or the cosine kernel, computes similarity as the
#    (...)
#    1573     Returns the cosine similarity between samples in X and Y.
#    1574 """
#    1575 # to avoid recursive import
# -> 1577 X, Y = check_pairwise_arrays(X, Y)
#    1579 X_normalized = normalize(X, copy=True)
#    1580 if X is Y:
#
# File ~/KnowledgeGraphs/venv/lib/python3.10/site-packages/sklearn/metrics/pairwise.py:173, in check_pairwise_arrays(X, Y, precomputed, dtype, accept_sparse, force_all_finite, copy)
#     164 else:
#     165     X = check_array(
#     166         X,
#     167         accept_sparse=accept_sparse,
#    (...)
#     171         estimator=estimator,
#     172     )
# --> 173     Y = check_array(
#     174         Y,
#     175         accept_sparse=accept_sparse,
#     176         dtype=dtype,
#     177         copy=copy,
#     178         force_all_finite=force_all_finite,
#     179         estimator=estimator,
#     180     )
#     182 if precomputed:
#     183     if X.shape[1] != Y.shape[0]:
#
# File ~/KnowledgeGraphs/venv/lib/python3.10/site-packages/sklearn/utils/validation.py:940, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     938     # If input is 1D raise error
#     939     if array.ndim == 1:
# --> 940         raise ValueError(
#     941             "Expected 2D array, got 1D array instead:\narray={}.\n"
#     942             "Reshape your data either using array.reshape(-1, 1) if "
#     943             "your data has a single feature or array.reshape(1, -1) "
#     944             "if it contains a single sample.".format(array)
#     945         )
#     947 if dtype_numeric and hasattr(array.dtype, "kind") and array.dtype.kind in "USV":
#     948     raise ValueError(
#     949         "dtype='numeric' is not compatible with arrays of bytes/strings."
#     950         "Convert your data to numeric values explicitly instead."
#     951     )
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %% [markdown]
# # Problem!
#
# There is a key figure missing from this graph!  (Hint: in Cypher, try the following command:
#
# ```sql
# MATCH (n:Node)
# WHERE n.name CONTAINS 'michelle'
# RETURN n
# ```
#
# In this next notebook, we are going to rectify this and build out the graph a little further.
